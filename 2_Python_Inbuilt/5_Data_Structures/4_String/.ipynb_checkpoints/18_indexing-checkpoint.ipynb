# %% [markdown]
# |Method          |Description                                             |
# |----------------|--------------------------------------------------------|
# |Indexing        |

# %% [markdown]
# ![string index.jpeg](data:image/jpeg;base64,...)

# %%
# string indexing

x = "python"
print(x[2])
# Out:
# t

# %% [markdown]
# --------------------------------------------------------------------------------
