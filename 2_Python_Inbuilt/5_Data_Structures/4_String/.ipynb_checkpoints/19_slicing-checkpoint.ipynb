# %% [markdown]
# |Method          |Description                                             |
# |----------------|--------------------------------------------------------|
# |Slicing         |

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %%
# string Slicing

x = "python"
print(x[0:4])
# Out:
# pyth

# %%
# string Slicing

x = "python"
print(x[0:5:2])
# Out:
# pto

# %% [markdown]
# --------------------------------------------------------------------------------
