# %% [raw]
# we could still style our data frame for many purposes; namely, for presenting data or better aesthetic.

# %% [markdown]
# ### ‘planets’ data available from seaborn for learning purposes.

# %%
import pandas as pd
import seaborn as sns

# %%
planets = sns.load_dataset('planets')
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %% [markdown]
# ### 1. Hiding Function

# %% [raw]
# #  Sometimes when you do analysis and presenting the result to the other, you only want to show the most important aspect. I
#
#    know when I present my Data Frame to the non-technical person, the question is often about the Index in their default number
#
#    such as “what is this number?”. For that reason, we could try to hide the index with the following code.

# %%
# Using hide_index() from the style function
 
planets.head(10).style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_47ec9152_9c57_11ea_82c1_3c77e6dc4ffa" ><thead>    <tr>        <th class="col_heading level0 col0" >method</th>        <th class="col_heading level0 col1" >number</th>        <th class="col_heading level0 col2" >orbital_period</th>        <th class="col_heading level0 col3" >mass</th>        <th class="col_heading level0 col4" >distance</th>        <th class="col_heading level0 col5" >year</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_47ec9152_9c57_11ea_82c1_3c77e6dc4ffarow0_col0" class="data row0 col0" >Radial Velocity</td>
#                         <td id="T_47ec9152_9c57_11ea_82c1_3c77e6dc4ffarow0_col1" class="data row0 col1" >1</td>
#                         <td id="T_47ec9152_9c57_11ea_82c1_3c77e6dc4ffarow0_col2" class="data row0 col2" >269.3</td>
#                         <td id="T_47ec9152_9c57_11ea_82c1_3c77e6dc4ffarow0_col3" class="data row0 col3" >7.1</td>
# ...

# %% [raw]
# #  In addition, we could try to hide unnecessary columns with the chaining method. Let’s say I don't want to show the ‘method’
#
#    and ‘year’ columns then we could write it with the following code.

# %%
# Using hide_columns to hide the unnecesary columns

planets.head(10).style.hide_index().hide_columns(['method','year'])
# Out:
# <style  type="text/css" >
# </style><table id="T_7d418b52_9c57_11ea_9014_3c77e6dc4ffa" ><thead>    <tr>        <th class="col_heading level0 col1" >number</th>        <th class="col_heading level0 col2" >orbital_period</th>        <th class="col_heading level0 col3" >mass</th>        <th class="col_heading level0 col4" >distance</th>    </tr></thead><tbody>
#                 <tr>
#                                         <td id="T_7d418b52_9c57_11ea_9014_3c77e6dc4ffarow0_col1" class="data row0 col1" >1</td>
#                         <td id="T_7d418b52_9c57_11ea_9014_3c77e6dc4ffarow0_col2" class="data row0 col2" >269.3</td>
#                         <td id="T_7d418b52_9c57_11ea_9014_3c77e6dc4ffarow0_col3" class="data row0 col3" >7.1</td>
#                         <td id="T_7d418b52_9c57_11ea_9014_3c77e6dc4ffarow0_col4" class="data row0 col4" >77.4</td>
#                     </tr>
#             <tr>
# ...

# %% [markdown]
# ### 2. Highlight Function

# %% [raw]
# #  There is a time when we want to present our data frame and only highlight the important number, for example the highest
#
#    number. In this case, we could use the built-in method to highlight it with the following code.

# %%
# Highlight the maximum number for each column

planets.head(10).style.highlight_max(color = 'yellow')
# Out:
# <style  type="text/css" >
#     #T_b48ca6b4_9c58_11ea_a53b_3c77e6dc4ffarow2_col5 {
#             background-color:  yellow;
#         }    #T_b48ca6b4_9c58_11ea_a53b_3c77e6dc4ffarow3_col3 {
#             background-color:  yellow;
#         }    #T_b48ca6b4_9c58_11ea_a53b_3c77e6dc4ffarow4_col4 {
#             background-color:  yellow;
#         }    #T_b48ca6b4_9c58_11ea_a53b_3c77e6dc4ffarow6_col2 {
#             background-color:  yellow;
#         }    #T_b48ca6b4_9c58_11ea_a53b_3c77e6dc4ffarow9_col1 {
#             background-color:  yellow;
# ...

# %%
# Highlight the minimum number for each column

planets.head(10).style.highlight_min(color = 'lightblue')
# Out:
# <style  type="text/css" >
#     #T_57a8c7a4_9c59_11ea_888b_3c77e6dc4ffarow0_col1 {
#             background-color:  lightblue;
#         }    #T_57a8c7a4_9c59_11ea_888b_3c77e6dc4ffarow1_col1 {
#             background-color:  lightblue;
#         }    #T_57a8c7a4_9c59_11ea_888b_3c77e6dc4ffarow2_col1 {
#             background-color:  lightblue;
#         }    #T_57a8c7a4_9c59_11ea_888b_3c77e6dc4ffarow3_col1 {
#             background-color:  lightblue;
#         }    #T_57a8c7a4_9c59_11ea_888b_3c77e6dc4ffarow4_col1 {
#             background-color:  lightblue;
#         }    #T_57a8c7a4_9c59_11ea_888b_3c77e6dc4ffarow5_col1 {
#             background-color:  lightblue;
#         }    #T_57a8c7a4_9c59_11ea_888b_3c77e6dc4ffarow5_col2 {
#             background-color:  lightblue;
#         }    #T_57a8c7a4_9c59_11ea_888b_3c77e6dc4ffarow6_col1 {
#             background-color:  lightblue;
#         }    #T_57a8c7a4_9c59_11ea_888b_3c77e6dc4ffarow6_col4 {
# ...

# %%
# Highlight the minimum number with lightblue color and the maximum number with yellow color

planets.head(10).style.highlight_max(color='yellow').highlight_min(color = 'lightblue')
# Out:
# <style  type="text/css" >
#     #T_7a7d9964_9c59_11ea_ae6a_3c77e6dc4ffarow0_col1 {
#             : ;
#             background-color:  lightblue;
#         }    #T_7a7d9964_9c59_11ea_ae6a_3c77e6dc4ffarow1_col1 {
#             : ;
#             background-color:  lightblue;
#         }    #T_7a7d9964_9c59_11ea_ae6a_3c77e6dc4ffarow2_col1 {
#             : ;
#             background-color:  lightblue;
#         }    #T_7a7d9964_9c59_11ea_ae6a_3c77e6dc4ffarow2_col5 {
#             background-color:  yellow;
#             : ;
#         }    #T_7a7d9964_9c59_11ea_ae6a_3c77e6dc4ffarow3_col1 {
#             : ;
#             background-color:  lightblue;
#         }    #T_7a7d9964_9c59_11ea_ae6a_3c77e6dc4ffarow3_col3 {
#             background-color:  yellow;
#             : ;
#         }    #T_7a7d9964_9c59_11ea_ae6a_3c77e6dc4ffarow4_col1 {
#             : ;
#             background-color:  lightblue;
#         }    #T_7a7d9964_9c59_11ea_ae6a_3c77e6dc4ffarow4_col4 {
# ...

# %% [raw]
# #  Instead of each column, you could actually highlight the minimum or maximum number for each row. I show it in the following
#
#    code.

# %%
# Adding Axis = 1 to change the direction from column to row

planets.head(10).style.highlight_max(color = 'yellow', axis =1)
# Out:
# <style  type="text/css" >
#     #T_c4bce11c_9c59_11ea_aec2_3c77e6dc4ffarow0_col5 {
#             background-color:  yellow;
#         }    #T_c4bce11c_9c59_11ea_aec2_3c77e6dc4ffarow1_col5 {
#             background-color:  yellow;
#         }    #T_c4bce11c_9c59_11ea_aec2_3c77e6dc4ffarow2_col5 {
#             background-color:  yellow;
#         }    #T_c4bce11c_9c59_11ea_aec2_3c77e6dc4ffarow3_col5 {
#             background-color:  yellow;
#         }    #T_c4bce11c_9c59_11ea_aec2_3c77e6dc4ffarow4_col5 {
#             background-color:  yellow;
#         }    #T_c4bce11c_9c59_11ea_aec2_3c77e6dc4ffarow5_col5 {
#             background-color:  yellow;
#         }    #T_c4bce11c_9c59_11ea_aec2_3c77e6dc4ffarow6_col5 {
#             background-color:  yellow;
#         }    #T_c4bce11c_9c59_11ea_aec2_3c77e6dc4ffarow7_col5 {
#             background-color:  yellow;
#         }    #T_c4bce11c_9c59_11ea_aec2_3c77e6dc4ffarow8_col5 {
#             background-color:  yellow;
# ...

# %% [raw]
# #  we could highlight the null value with the following code.

# %%
# Higlight the null value

planets.head(10).style.highlight_null(null_color = 'red')
# Out:
# <style  type="text/css" >
#     #T_e8aadbac_9c59_11ea_bdbd_3c77e6dc4ffarow7_col3 {
#             background-color:  red;
#         }</style><table id="T_e8aadbac_9c59_11ea_bdbd_3c77e6dc4ffa" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >method</th>        <th class="col_heading level0 col1" >number</th>        <th class="col_heading level0 col2" >orbital_period</th>        <th class="col_heading level0 col3" >mass</th>        <th class="col_heading level0 col4" >distance</th>        <th class="col_heading level0 col5" >year</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e8aadbac_9c59_11ea_bdbd_3c77e6dc4ffalevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e8aadbac_9c59_11ea_bdbd_3c77e6dc4ffarow0_col0" class="data row0 col0" >Radial Velocity</td>
# ...

# %% [markdown]
# ### 3. Gradient Function

# %% [raw]
# #  While presenting your data, we could also use all the information as the main way to present the data. I often present the
#
#    data with a background color to highlight which number is in the lower area and where is the one in the higher area. Let’s
#
#    use the example by the following code.

# %%
# Gradient background color for the numerical columns

planets.head(10).style.background_gradient(cmap = 'Blues')
# Out:
# C:\Users\deepusuresh\Anaconda3\lib\site-packages\matplotlib\colors.py:512: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_1401a5de_9c5a_11ea_b756_3c77e6dc4ffarow0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1401a5de_9c5a_11ea_b756_3c77e6dc4ffarow0_col2 {
#             background-color:  #edf4fc;
#             color:  #000000;
#         }    #T_1401a5de_9c5a_11ea_b756_3c77e6dc4ffarow0_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1401a5de_9c5a_11ea_b756_3c77e6dc4ffarow0_col4 {
#             background-color:  #4f9bcb;
#             color:  #000000;
#         }    #T_1401a5de_9c5a_11ea_b756_3c77e6dc4ffarow0_col5 {
#             background-color:  #3787c0;
#             color:  #000000;
#         }    #T_1401a5de_9c5a_11ea_b756_3c77e6dc4ffarow1_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
# ...

# %% [raw]
# #  With the background_gradient function, we could color the data frame as a gradient. The color would depend on the cmap
#
#    parameter where the parameter is accepting colormaps from the matplotlib library.
#
# #  We could also use a bar chart as our gradient background color. Let me show it in the example below.

# %%
# Sort the values by the year column then creating a bar chart as the background

planets.head(10).sort_values(by = 'year').style.bar(color= 'lightblue')
# Out:
# <style  type="text/css" >
#     #T_af1b6998_9c5b_11ea_8e79_3c77e6dc4ffarow0_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_af1b6998_9c5b_11ea_8e79_3c77e6dc4ffarow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 38.6%, transparent 38.6%);
#         }    #T_af1b6998_9c5b_11ea_8e79_3c77e6dc4ffarow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 3.2%, transparent 3.2%);
#         }    #T_af1b6998_9c5b_11ea_8e79_3c77e6dc4ffarow0_col5 {
#             width:  10em;
#              height:  80%;
#         }    #T_af1b6998_9c5b_11ea_8e79_3c77e6dc4ffarow1_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_af1b6998_9c5b_11ea_8e79_3c77e6dc4ffarow1_col2 {
#             width:  10em;
#              height:  80%;
# ...

# %% [raw]
# #  As we could see above, we now highlight the number from the lowest to the highest number in a different way than the
#
#    background_gradient function is. We could also see the index is not in order because of the sort function; it is better to
#
#    hide the index as I told you in the passage above.

# %% [markdown]
# ### 4. Custom Function

# %% [raw]
# #  Both of those methods take a function (and some other keyword arguments) and apply our function to the DataFrame in a
#
#    certain way. Let’s say that I have a threshold that any number below 20 should be colored red. We could do that by using the
#
#    following code.
#
#
#        - Styler.applymap: element-wise
#
#        - Styler.apply: column-/row-/table-wise

# %%
# Create the function to color the numerical value into red color

def color_below_20_red(value):
    if type(value) == type(''):
        return 'color:black'
    else:
        color = 'red' if value <= 20 else 'black'
        return 'color: {}'.format(color)
    
# We apply the function to all the element in the data frame by using the applymap function

planets.head(10).style.applymap(color_below_20_red)
# Out:
# <style  type="text/css" >
#     #T_10b0fc94_9c5c_11ea_b29d_3c77e6dc4ffarow0_col0 {
#             color: black;
#         }    #T_10b0fc94_9c5c_11ea_b29d_3c77e6dc4ffarow0_col1 {
#             color:  red;
#         }    #T_10b0fc94_9c5c_11ea_b29d_3c77e6dc4ffarow0_col2 {
#             color:  black;
#         }    #T_10b0fc94_9c5c_11ea_b29d_3c77e6dc4ffarow0_col3 {
#             color:  red;
#         }    #T_10b0fc94_9c5c_11ea_b29d_3c77e6dc4ffarow0_col4 {
#             color:  black;
#         }    #T_10b0fc94_9c5c_11ea_b29d_3c77e6dc4ffarow0_col5 {
#             color:  black;
#         }    #T_10b0fc94_9c5c_11ea_b29d_3c77e6dc4ffarow1_col0 {
#             color: black;
#         }    #T_10b0fc94_9c5c_11ea_b29d_3c77e6dc4ffarow1_col1 {
#             color:  red;
#         }    #T_10b0fc94_9c5c_11ea_b29d_3c77e6dc4ffarow1_col2 {
#             color:  black;
#         }    #T_10b0fc94_9c5c_11ea_b29d_3c77e6dc4ffarow1_col3 {
#             color:  red;
# ...

# %% [raw]
# #  Just like that, every single number below or equal to 20 would be colored red and the rest is in black.
